# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv('requests.csv') #parse_dates=['date'], low_memory = False)

# %%
df
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 0       26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1       26591458  10/31/2013 01:14:02 AM  10/31/2013 01:30:34 AM   NYPD
# 2       26591641  10/31/2013 12:31:17 AM  10/31/2013 02:41:36 AM   NYPD
# 3       26590446  10/31/2013 12:11:58 AM  10/31/2013 01:54:38 AM   NYPD
# 4       26590757  10/31/2013 12:00:00 AM                     NaN    HPD
# ...          ...                     ...                     ...    ...
# 7400    26431018  10/04/2013 01:08:14 AM  10/04/2013 07:09:47 AM   NYPD
# 7401    26437944  10/04/2013 12:48:00 AM  10/04/2013 12:00:00 PM   DSNY
# 7402    26431986  10/04/2013 12:28:01 AM  10/04/2013 03:02:09 AM   NYPD
# 7403    26437764  10/04/2013 12:14:00 AM  10/04/2013 12:14:00 AM    DEP
# 7404    26434084  10/04/2013 12:04:00 AM                     NaN    DEP
#
#                                             Agency Name  \
# ...

# %%
df[df.home_team == 'Wisła Kraków']
# Out:
#       country              league     home_team              away_team  \
# 15721  Poland  Poland Ekstraklasa  Wisła Kraków          Polonia Bytom
# 15742  Poland  Poland Ekstraklasa  Wisła Kraków           Ruch Chorzów
# 15746  Poland  Poland Ekstraklasa  Wisła Kraków            Widzew Łódź
# 15761  Poland  Poland Ekstraklasa  Wisła Kraków          Lechia Gdańsk
# 15786  Poland  Poland Ekstraklasa  Wisła Kraków         Odra Wodzisław
# ...       ...                 ...           ...                    ...
# 17562  Poland  Poland Ekstraklasa  Wisła Kraków  Jagiellonia Białystok
# 17580  Poland  Poland Ekstraklasa  Wisła Kraków            Lech Poznań
# 17586  Poland  Poland Ekstraklasa  Wisła Kraków         Zagłębie Lubin
# 17602  Poland  Poland Ekstraklasa  Wisła Kraków          Lechia Gdańsk
# 17617  Poland  Poland Ekstraklasa  Wisła Kraków          Śląsk Wrocław
#
#             date     season  home_team_goal  away_team_goal
# ...

# %%
df[(2010<=df.date.dt.year)&(df.date.dt.year <= 2015)]
# Out:
#            country                    league                home_team  \
# 376        Belgium    Belgium Jupiler League           RSC Anderlecht
# 378        Belgium    Belgium Jupiler League       Sporting Charleroi
# 381        Belgium    Belgium Jupiler League              KV Mechelen
# 404        Belgium    Belgium Jupiler League           Club Brugge KV
# 405        Belgium    Belgium Jupiler League        Standard de Liège
# ...            ...                       ...                      ...
# 25974  Switzerland  Switzerland Super League            FC St. Gallen
# 25975  Switzerland  Switzerland Super League                 FC Vaduz
# 25976  Switzerland  Switzerland Super League  Grasshopper Club Zürich
# 25977  Switzerland  Switzerland Super League                   Lugano
# 25978  Switzerland  Switzerland Super League           BSC Young Boys
#
#                away_team       date     season  home_team_goal  away_team_goal
# ...

# %%
df[((df.home_team == 'Legia')|(df.away_team == 'Wisła kraków'))&
   ((df.home_team == 'Wisła kraków')|(df.away_team == 'Legia'))]
# Out:
# Empty DataFrame
# Columns: [country, league, home_team, away_team, date, season, home_team_goal, away_team_goal]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('matches.csv', parse_dates=['date'], low_memory=False)
df
df[(df.date.dt.year.between(2010, 2015)) & 
   (df.home_team.isin(["Legia Warszawa", "Wisła Kraków"])) &
  (df.away_team.isin(["Legia Warszawa", "Wisła Kraków"]))]
# Out:
#       country              league       home_team       away_team       date  \
# 16121  Poland  Poland Ekstraklasa  Legia Warszawa    Wisła Kraków 2010-05-08
# 16234  Poland  Poland Ekstraklasa    Wisła Kraków  Legia Warszawa 2010-11-12
# 16362  Poland  Poland Ekstraklasa  Legia Warszawa    Wisła Kraków 2011-05-21
# 16575  Poland  Poland Ekstraklasa    Wisła Kraków  Legia Warszawa 2012-03-30
# 16677  Poland  Poland Ekstraklasa  Legia Warszawa    Wisła Kraków 2011-10-02
# 16799  Poland  Poland Ekstraklasa    Wisła Kraków  Legia Warszawa 2013-04-13
# 16900  Poland  Poland Ekstraklasa  Legia Warszawa    Wisła Kraków 2012-10-05
# 16939  Poland  Poland Ekstraklasa    Wisła Kraków  Legia Warszawa 2013-10-06
# 17067  Poland  Poland Ekstraklasa  Legia Warszawa    Wisła Kraków 2014-03-16
# 17290  Poland  Poland Ekstraklasa  Legia Warszawa    Wisła Kraków 2015-03-15
# 17394  Poland  Poland Ekstraklasa    Wisła Kraków  Legia Warszawa 2014-09-21
# ...

# %%
df['goals_difrenc'] = abs(df.home_team_goal - df.away_team_goal)
df.nlargest(10, 'goals_diference')
# Out:
# --------------------------------------------------------------
# KeyError                     Traceback (most recent call last)
# c:\users\kurs\workspace\projects\bootcamp\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'goals_diference'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                     Traceback (most recent call last)
# <ipython-input-23-80e140cb6969> in <module>
# ...
